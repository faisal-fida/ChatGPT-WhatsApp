# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
options = uc.ChromeOptions()
options.add_argument("--incognito")
browser = uc.Chrome(options=options, version_main=0)
browser1 = uc.Chrome(version_main=0)
browser.set_page_load_timeout(15)
browser.get("https://chat.openai.com/chat")
browser1.get('https://web.whatsapp.com')
print('QRCode synchronization')
time.sleep(30)

# %%
def send_Question(question):
    textarea = browser.find_element(By.TAG_NAME, "textarea")
    if textarea.is_displayed():
        textarea.send_keys(question)
        textarea.send_keys(Keys.RETURN)

# %%
def get_Answer():
    while len(browser.find_elements(By.CSS_SELECTOR,".result-streaming")) > 0:
        time.sleep(0.1)

    page_elements = browser.find_elements(By.CSS_SELECTOR,".flex.flex-col.items-center > div")
    last_element = page_elements[-2]
    return last_element.text

# %%
def send_Answer(answer):
    sendBoxPath = '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]/div/div[1]'
    sendBox = browser1.find_elements(By.XPATH, sendBoxPath)[0]
    sendBox.click()
    sendBox.send_keys(answer)
    send_button = browser1.find_element(By.XPATH,"//span[@data-icon='send']")
    send_button.click()
    browser1.find_elements(By.CSS_SELECTOR, "[data-testid='pinned2']")[2].click()

# %%
for i in range(5):
    try:
        WebDriverWait(browser1, 9900).until(EC.presence_of_element_located((By.CSS_SELECTOR, "[aria-label='1 unread message']")))
    finally:
        browser1.find_element(By.CSS_SELECTOR,"[aria-label='1 unread message']").click()
        question = browser1.find_elements(By.CLASS_NAME,'_21Ahp')[-1].text
        

    send_Question(question)
    answer = get_Answer()
    send_Answer(answer)
# Out:
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# Updated session
# ...
